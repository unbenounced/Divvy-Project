# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 500)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

# %%
BikeShareData_202304 = pd.read_csv('/Users/ericm/Documents/BikeShareData_20241111/202304-divvy-tripdata.csv')
BikeShareData_202305 = pd.read_csv('/Users/ericm/Documents/BikeShareData_20241111/202305-divvy-tripdata.csv')

# %%
BikeShareData_2023AprMay = pd.concat([BikeShareData_202304, BikeShareData_202305], ignore_index=True)
BikeShareData_2023AprMay
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        8FE8F7D9C10E88C7  electric_bike  2023-04-02 08:37:28
# 1        34E4ED3ADF1D821B  electric_bike  2023-04-19 11:29:02
# 2        5296BF07A2F77CB5  electric_bike  2023-04-19 08:41:22
# 3        40759916B76D5D52  electric_bike  2023-04-19 13:31:30
# 4        77A96F460101AC63  electric_bike  2023-04-19 12:05:36
# ...                   ...            ...                  ...
# 1031412  48BDA26F34445546  electric_bike  2023-05-18 10:26:43
# 1031413  573025E5EDE10DE1  electric_bike  2023-05-17 14:32:48
# 1031414  D88D48898C6FB63E  electric_bike  2023-05-17 07:59:29
# 1031415  4692DCD2F87497F5  electric_bike  2023-05-18 08:34:48
# 1031416  6ACB7E383473D019  electric_bike  2023-05-29 21:16:58
#
#                     ended_at                       start_station_name  \
# 0        2023-04-02 08:41:37                                      NaN
# 1        2023-04-19 11:52:12                                      NaN
# ...

# %%
BikeShareData_2023AprMay['ride_id'].value_counts(
# Out:
# ride_id
# 8FE8F7D9C10E88C7    1
# DBC67DEDFD01C785    1
# F157273F4A83F0EC    1
# 7B6E13D12BE3DBC9    1
# DD870EC9F5DE6ECC    1
#                    ..
# 34B25E470E9B216B    1
# 843243DEB324AD7B    1
# A554986088910FD1    1
# 34D507B2D9E5581C    1
# 6ACB7E383473D019    1
# Name: count, Length: 1031417, dtype: int64

# %%
BikeShareData_2023AprMay.to_csv('BikeShareData_2023AprMay.csv', index=False)
